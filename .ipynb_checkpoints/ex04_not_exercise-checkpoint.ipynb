# %% [raw]
# import warnings
# warnings.simplefilter("ignore")
# import pandas as pd
#
# not_exercise = pd.read_excel("./datas/reason_not_exercise.xlsx",header=1)
# not_exercise

# %%
# 칼럼 (열) 리스트 작업
print(not_exercise.columns[1])
not_exercise.rename(columns={'구분별(1)':'대분류','구분별(2)':'분류'},inplace=True) # 칼럼 이름 변경
print(not_exercise.columns[1:3])
not_exercise.drop(columns='시점',inplace=True)
not_exercise
# Out:
# 대분류
# Index(['대분류', '분류'], dtype='object')
#       대분류            분류  운동을 할 충분한 시간이 없어서  함께 운동을 할 사람이 없어서  \
# 0     서울시            소계               46.8               5.0
# 1      성별            남자               52.4               4.4
# 2     NaN            여자               42.5               5.6
# 3     연령별           10대               55.3               4.8
# 4     NaN           20대               46.0               4.2
# 5     NaN           30대               59.9               5.2
# 6     NaN           40대               54.1               3.9
# 7     NaN           50대               46.1               6.2
# 8     NaN        60대 이상               26.6               6.0
# 9     학력별         중졸 이하               24.7               6.2
# 10    NaN         고졸 이하               44.3               5.3
# 11    NaN         대졸 이하               53.1               4.7
# 12    NaN        대학원 이상               61.2               3.0
# 13    소득별      100만원 미만               10.7               8.4
# ...

# %%
# not_exercise
not_exercise.drop(index=range(22, 52), inplace=True)#22~51행까지 삭제
not_exercise
# Out:
#       대분류            분류  운동을 할 충분한 시간이 없어서  함께 운동을 할 사람이 없어서  \
# 0     서울시            소계               46.8               5.0
# 1      성별            남자               52.4               4.4
# 2     NaN            여자               42.5               5.6
# 3     연령별           10대               55.3               4.8
# 4     NaN           20대               46.0               4.2
# 5     NaN           30대               59.9               5.2
# 6     NaN           40대               54.1               3.9
# 7     NaN           50대               46.1               6.2
# 8     NaN        60대 이상               26.6               6.0
# 9     학력별         중졸 이하               24.7               6.2
# 10    NaN         고졸 이하               44.3               5.3
# 11    NaN         대졸 이하               53.1               4.7
# 12    NaN        대학원 이상               61.2               3.0
# 13    소득별      100만원 미만               10.7               8.4
# ...

# %%
not_exercise.loc[2, "대분류"] = "성별" # 2행의 NaN을 찾아 성별로 변경함
not_exercise.loc[2]
not_ex_sex = not_exercise[not_exercise['대분류'] == '성별'].copy() # 깊은 복사
not_ex_sex
# Out:
#   대분류  분류  운동을 할 충분한 시간이 없어서  함께 운동을 할 사람이 없어서  운동을 할 만한 장소가 없어서  운동을 싫어해서  \
# 1  성별  남자               52.4               4.4               4.9      32.4
# 2  성별  여자               42.5               5.6               3.9      41.0
#
#    운동을 할 충분한 비용이 없어서   기타
# 1                4.9  1.1
# 2                5.4  1.7

# %%
not_ex_sex.drop(columns="대분류",inplace=True)
not_ex_sex
# Out:
#    분류  운동을 할 충분한 시간이 없어서  함께 운동을 할 사람이 없어서  운동을 할 만한 장소가 없어서  운동을 싫어해서  \
# 1  남자               52.4               4.4               4.9      32.4
# 2  여자               42.5               5.6               3.9      41.0
#
#    운동을 할 충분한 비용이 없어서   기타
# 1                4.9  1.1
# 2                5.4  1.7

# %%
import matplotlib as plt

fig, ax = plt.subprocess(1, 2, figsiz(16,8))#1 행 2열

plt.rc("font",familly="Malgun Gothic")
not_ex_sex['운동을 할 충분한 시간이 없어서'].plot.ple(ax=ax[0],autopct="%1.f%%", startangle=90)
ax[0].set_title('운동을 할 충분한 시간이 없어서')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 3
#       1 import matplotlib as plt
# ----> 3 fig, ax = plt.subprocess(1, 2, figsiz(16,8))#1 행 2열
#       5 plt.rc("font",familly="Malgun Gothic")
#       6 not_ex_sex['운동을 할 충분한 시간이 없어서'].plot.ple(ax=ax[0],autopct="%1.f%%", startangle=90)
#
# NameError: name 'figsiz' is not defined
