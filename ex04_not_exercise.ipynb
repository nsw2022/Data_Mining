# %% [markdown]
# ## 서울시 운동을 하지 않는 이유 통계
# ### excel 파일을 읽기 - pandas.read_excel(파일)

# %%
import pandas as pd
import warnings
warnings.simplefilter('ignore')

# 제목행의 1번 인덱스만 출력(0번은 숨김)
not_exercise = pd.read_excel("./datas/reason_not_exercise.xlsx", header=1)
not_exercise
# Out:
#         시점 구분별(1)        구분별(2)  운동을 할 충분한 시간이 없어서  함께 운동을 할 사람이 없어서  \
# 0   2019.0    서울시            소계               46.8               5.0
# 1      NaN     성별            남자               52.4               4.4
# 2      NaN    NaN            여자               42.5               5.6
# 3      NaN    연령별           10대               55.3               4.8
# 4      NaN    NaN           20대               46.0               4.2
# 5      NaN    NaN           30대               59.9               5.2
# 6      NaN    NaN           40대               54.1               3.9
# 7      NaN    NaN           50대               46.1               6.2
# 8      NaN    NaN        60대 이상               26.6               6.0
# 9      NaN    학력별         중졸 이하               24.7               6.2
# 10     NaN    NaN         고졸 이하               44.3               5.3
# 11     NaN    NaN         대졸 이하               53.1               4.7
# 12     NaN    NaN        대학원 이상               61.2               3.0
# ...

# %%
not_exercise.columns[0]
# Out:
# '시점'

# %%
# 칼럼 삭제 - 객체.drop() #inplace=True (즉시 실행) 커밋같은친구
not_exercise.drop(columns='시점', inplace=True)

# %%
not_exercise
# Out:
#    구분별(1)        구분별(2)  운동을 할 충분한 시간이 없어서  함께 운동을 할 사람이 없어서  \
# 0     서울시            소계               46.8               5.0
# 1      성별            남자               52.4               4.4
# 2     NaN            여자               42.5               5.6
# 3     연령별           10대               55.3               4.8
# 4     NaN           20대               46.0               4.2
# 5     NaN           30대               59.9               5.2
# 6     NaN           40대               54.1               3.9
# 7     NaN           50대               46.1               6.2
# 8     NaN        60대 이상               26.6               6.0
# 9     학력별         중졸 이하               24.7               6.2
# 10    NaN         고졸 이하               44.3               5.3
# 11    NaN         대졸 이하               53.1               4.7
# 12    NaN        대학원 이상               61.2               3.0
# 13    소득별      100만원 미만               10.7               8.4
# ...

# %%
# 칼럼명 변경 - 객체.rename()
not_exercise.rename(columns={'구분별(1)':'대분류', '구분별(2)':'분류'}, inplace=True)
not_exercise
# Out:
#       대분류            분류  운동을 할 충분한 시간이 없어서  함께 운동을 할 사람이 없어서  \
# 0     서울시            소계               46.8               5.0
# 1      성별            남자               52.4               4.4
# 2     NaN            여자               42.5               5.6
# 3     연령별           10대               55.3               4.8
# 4     NaN           20대               46.0               4.2
# 5     NaN           30대               59.9               5.2
# 6     NaN           40대               54.1               3.9
# 7     NaN           50대               46.1               6.2
# 8     NaN        60대 이상               26.6               6.0
# 9     학력별         중졸 이하               24.7               6.2
# 10    NaN         고졸 이하               44.3               5.3
# 11    NaN         대졸 이하               53.1               4.7
# 12    NaN        대학원 이상               61.2               3.0
# 13    소득별      100만원 미만               10.7               8.4
# ...

# %%
# 행 삭제 - 객체.drop(index=range(시작행, 끝행-1))
not_exercise.drop(index=range(22, 52), inplace=True)
not_exercise
# Out:
#       대분류            분류  운동을 할 충분한 시간이 없어서  함께 운동을 할 사람이 없어서  \
# 0     서울시            소계               46.8               5.0
# 1      성별            남자               52.4               4.4
# 2     NaN            여자               42.5               5.6
# 3     연령별           10대               55.3               4.8
# 4     NaN           20대               46.0               4.2
# 5     NaN           30대               59.9               5.2
# 6     NaN           40대               54.1               3.9
# 7     NaN           50대               46.1               6.2
# 8     NaN        60대 이상               26.6               6.0
# 9     학력별         중졸 이하               24.7               6.2
# 10    NaN         고졸 이하               44.3               5.3
# 11    NaN         대졸 이하               53.1               4.7
# 12    NaN        대학원 이상               61.2               3.0
# 13    소득별      100만원 미만               10.7               8.4
# ...

# %%
# 2행의 NaN을 '성별'로 변경 - '대분류' 컬럼의 2행을 수정
not_exercise.loc[2, '대분류'] = '성별'
not_exercise
# Out:
#       대분류            분류  운동을 할 충분한 시간이 없어서  함께 운동을 할 사람이 없어서  \
# 0     서울시            소계               46.8               5.0
# 1      성별            남자               52.4               4.4
# 2      성별            여자               42.5               5.6
# 3     연령별           10대               55.3               4.8
# 4     NaN           20대               46.0               4.2
# 5     NaN           30대               59.9               5.2
# 6     NaN           40대               54.1               3.9
# 7     NaN           50대               46.1               6.2
# 8     NaN        60대 이상               26.6               6.0
# 9     학력별         중졸 이하               24.7               6.2
# 10    NaN         고졸 이하               44.3               5.3
# 11    NaN         대졸 이하               53.1               4.7
# 12    NaN        대학원 이상               61.2               3.0
# 13    소득별      100만원 미만               10.7               8.4
# ...

# %%
not_ex_sex = not_exercise[not_exercise['대분류'] == '성별'].copy()  #깊은 복사
not_ex_sex
# Out:
#   대분류  분류  운동을 할 충분한 시간이 없어서  함께 운동을 할 사람이 없어서  운동을 할 만한 장소가 없어서  운동을 싫어해서  \
# 1  성별  남자               52.4               4.4               4.9      32.4
# 2  성별  여자               42.5               5.6               3.9      41.0
#
#    운동을 할 충분한 비용이 없어서   기타
# 1                4.9  1.1
# 2                5.4  1.7

# %%
# 대분류 칼럼 삭제
not_ex_sex.drop(columns='대분류', inplace=True)
not_ex_sex
# Out:
#    분류  운동을 할 충분한 시간이 없어서  함께 운동을 할 사람이 없어서  운동을 할 만한 장소가 없어서  운동을 싫어해서  \
# 1  남자               52.4               4.4               4.9      32.4
# 2  여자               42.5               5.6               3.9      41.0
#
#    운동을 할 충분한 비용이 없어서   기타
# 1                4.9  1.1
# 2                5.4  1.7

# %%
# index를 '분류'로 세팅
not_ex_sex.set_index('분류', inplace=True)
not_ex_sex
# Out:
#     운동을 할 충분한 시간이 없어서  함께 운동을 할 사람이 없어서  운동을 할 만한 장소가 없어서  운동을 싫어해서  \
# 분류
# 남자               52.4               4.4               4.9      32.4
# 여자               42.5               5.6               3.9      41.0
#
#     운동을 할 충분한 비용이 없어서   기타
# 분류
# 남자                4.9  1.1
# 여자                5.4  1.7

# %% [markdown]
# ### figure : 그래프를 그릴 공간(종이)
# ### ax(axis) : 그 공간중 내가 사용할 부분 - 축
# ### subplots() - 작은 그래프(1행2열)

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 2) 
plt.rc('font', family='Malgun Gothic')

not_ex_sex['운동을 할 충분한 시간이 없어서'].plot.pie(ax=ax[0], 
                autopct='%.1f%%', startangle=90)
ax[0].set_title('운동을 할 충분한 시간이 없어서')
ax[0].set_ylabel('')

not_ex_sex['운동을 싫어해서'].plot.pie(ax=ax[1], 
                autopct='%.1f%%', startangle=90)
ax[1].set_title('운동을 싫어해서')
ax[1].set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %% [markdown]
# ## 연령별 분석

# %%
# not_exercise.loc[4, '대분류'] = '연령별'
# not_exercise.loc[5, '대분류'] = '연령별'
for i in range(4, 9):
    not_exercise.loc[i, '대분류'] = "연령별"

not_exercise
# Out:
#       대분류            분류  운동을 할 충분한 시간이 없어서  함께 운동을 할 사람이 없어서  \
# 0     서울시            소계               46.8               5.0
# 1      성별            남자               52.4               4.4
# 2      성별            여자               42.5               5.6
# 3     연령별           10대               55.3               4.8
# 4     연령별           20대               46.0               4.2
# 5     연령별           30대               59.9               5.2
# 6     연령별           40대               54.1               3.9
# 7     연령별           50대               46.1               6.2
# 8     연령별        60대 이상               26.6               6.0
# 9     학력별         중졸 이하               24.7               6.2
# 10    NaN         고졸 이하               44.3               5.3
# 11    NaN         대졸 이하               53.1               4.7
# 12    NaN        대학원 이상               61.2               3.0
# 13    소득별      100만원 미만               10.7               8.4
# ...

# %%
not_exercise['대분류'] == "연령별"
# Out:
# 0     False
# 1     False
# 2     False
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# Name: 대분류, dtype: bool

# %%
not_ex_age = not_exercise[not_exercise['대분류']=='연령별'].copy()
not_ex_age
# Out:
#    대분류      분류  운동을 할 충분한 시간이 없어서  함께 운동을 할 사람이 없어서  운동을 할 만한 장소가 없어서  \
# 3  연령별     10대               55.3               4.8               3.9
# 4  연령별     20대               46.0               4.2               4.5
# 5  연령별     30대               59.9               5.2               2.9
# 6  연령별     40대               54.1               3.9               2.9
# 7  연령별     50대               46.1               6.2               4.5
# 8  연령별  60대 이상               26.6               6.0               6.6
#
#    운동을 싫어해서  운동을 할 충분한 비용이 없어서   기타
# 3      32.6                3.5    -
# 4      38.8                6.4  0.1
# 5      27.3                4.5  0.2
# 6      35.5                3.3  0.4
# 7      36.8                5.6  0.8
# 8      48.7                6.6  5.6

# %%
not_ex_age.drop(columns='대분류', inplace=True)
not_ex_age
# Out:
#        분류  운동을 할 충분한 시간이 없어서  함께 운동을 할 사람이 없어서  운동을 할 만한 장소가 없어서  운동을 싫어해서  \
# 3     10대               55.3               4.8               3.9      32.6
# 4     20대               46.0               4.2               4.5      38.8
# 5     30대               59.9               5.2               2.9      27.3
# 6     40대               54.1               3.9               2.9      35.5
# 7     50대               46.1               6.2               4.5      36.8
# 8  60대 이상               26.6               6.0               6.6      48.7
#
#    운동을 할 충분한 비용이 없어서   기타
# 3                3.5    -
# 4                6.4  0.1
# 5                4.5  0.2
# 6                3.3  0.4
# 7                5.6  0.8
# 8                6.6  5.6

# %%
not_ex_age.set_index('분류', inplace=True)
not_ex_age
# Out:
#         운동을 할 충분한 시간이 없어서  함께 운동을 할 사람이 없어서  운동을 할 만한 장소가 없어서  운동을 싫어해서  \
# 분류
# 10대                  55.3               4.8               3.9      32.6
# 20대                  46.0               4.2               4.5      38.8
# 30대                  59.9               5.2               2.9      27.3
# 40대                  54.1               3.9               2.9      35.5
# 50대                  46.1               6.2               4.5      36.8
# 60대 이상               26.6               6.0               6.6      48.7
#
#         운동을 할 충분한 비용이 없어서   기타
# 분류
# 10대                   3.5    -
# 20대                   6.4  0.1
# 30대                   4.5  0.2
# 40대                   3.3  0.4
# 50대                   5.6  0.8
# 60대 이상                6.6  5.6

# %%
f, ax = plt.subplots(1, 3, figsize=(16, 8))
exploed_setting = [0.05, 0.05, 0.05, 0.05, 0.05, 0.05] # 파이차트 요소간 간격

plt.rc('font', family='Malgun Gothic')

not_ex_age['운동을 할 충분한 시간이 없어서'].plot.pie(ax=ax[0], 
                explode=exploed_setting, autopct='%.1f%%', startangle=90)
ax[0].set_title('운동을 할 충분한 시간이 없어서')
ax[0].set_ylabel('')

not_ex_age['함께 운동을 할 사람이 없어서'].plot.pie(ax=ax[1], 
                explode=exploed_setting, autopct='%.1f%%', startangle=90)
ax[1].set_title('함께 운동을 할 사람이 없어서')
ax[1].set_ylabel('')

not_ex_age['운동을 할 만한 장소가 없어서'].plot.pie(ax=ax[2], 
                explode=exploed_setting, autopct='%.1f%%', startangle=90)
ax[2].set_title('운동을 할 만한 장소가 없어서')
ax[2].set_ylabel('')
# Out:
# Text(0, 0.5, '')
