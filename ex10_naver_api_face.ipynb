# %% [markdown]
# ### 네이버 얼굴 인식(CFR)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread("./datas/face_detection1.jpg")
plt.rc('font', family='Malgun Gothic')
plt.figure(figsize=(8, 6)) # 사이즈 설정
plt.imshow(img)
plt.show()

# %%
import requests
import json


client_id = "KBSm4KBobPGW62mdUrCX"
client_secret = "7N3EvKDn7e"

# url = "https://openapi.naver.com/v1/vision/face" // 얼굴감지
url = "https://openapi.naver.com/v1/vision/celebrity"  # 마지막 경로를 face로 변경
# files = {'image': open('./datas/face_detection1.jpg', 'rb')}
files = {'image': open('./datas/aboutme.jpg', 'rb')}
headers = {'X-Naver-Client-Id': client_id, 'X-Naver-Client-Secret': client_secret }

# post() 로 보내기
response = requests.post(url,  files=files, headers=headers)
# print(response.text)
# print(type(response.text)) # type = str

parsed = json.loads(response.text)
# print(parsed)
# print(type(parsed)) # 파이썬 딕셔너리

# 딕셔너리를 json.dumps() 처리하면 json 데이터가 됨
# confidence : 일치률
# value : 값
print( json.dumps(parsed, indent=4, sort_keys=False, ensure_ascii=False) )
print( type( json.dumps(parsed, indent=4, sort_keys=False, ensure_ascii=False) )  )

test =  json.dumps(parsed, indent=4, sort_keys=False, ensure_ascii=False)
test_name = parsed['faces'][0]['celebrity']['value']
# Out:
# {
#     "info": {
#         "size": {
#             "width": 354,
#             "height": 472
#         },
#         "faceCount": 1
#     },
#     "faces": [
#         {
#             "celebrity": {
#                 "value": "한승현",
#                 "confidence": 0.606362
#             }
#         }
#     ]
# }
# <class 'str'>

# %%
import requests
import json


client_id = "KBSm4KBobPGW62mdUrCX"
client_secret = "7N3EvKDn7e"

# url = "https://openapi.naver.com/v1/vision/face" // 얼굴감지
url = "https://openapi.naver.com/v1/vision/face"  # 마지막 경로를 face로 변경
# files = {'image': open('./datas/face_detection1.jpg', 'rb')}
files = {'image': open('./datas/aboutme.jpg', 'rb')}

headers = {'X-Naver-Client-Id': client_id, 'X-Naver-Client-Secret': client_secret }

# post() 로 보내기
response = requests.post(url,  files=files, headers=headers)


parsed = json.loads(response.text)

print( json.dumps(parsed, indent=4, sort_keys=False, ensure_ascii=False) )
print( type( json.dumps(parsed, indent=4, sort_keys=False, ensure_ascii=False) )  )
# Out:
# {
#     "info": {
#         "size": {
#             "width": 354,
#             "height": 472
#         },
#         "faceCount": 1
#     },
#     "faces": [
#         {
#             "roi": {
#                 "x": 93,
#                 "y": 130,
#                 "width": 160,
#                 "height": 160
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 136,
#                     "y": 176
#                 },
#                 "rightEye": {
#                     "x": 209,
#                     "y": 173
#                 },
#                 "nose": {
#                     "x": 174,
#                     "y": 214
#                 },
#                 "leftMouth": {
#                     "x": 141,
#                     "y": 258
#                 },
#                 "rightMouth": {
#                     "x": 208,
#                     "y": 258
#                 }
#             },
#             "gender": {
# ...

# %%
detect_result = json.loads(response.text)
detect_result
# Out:
# {'info': {'size': {'width': 354, 'height': 472}, 'faceCount': 1},
#  'faces': [{'roi': {'x': 93, 'y': 130, 'width': 160, 'height': 160},
#    'landmark': {'leftEye': {'x': 136, 'y': 176},
#     'rightEye': {'x': 209, 'y': 173},
#     'nose': {'x': 174, 'y': 214},
#     'leftMouth': {'x': 141, 'y': 258},
#     'rightMouth': {'x': 208, 'y': 258}},
#    'gender': {'value': 'male', 'confidence': 0.999973},
#    'age': {'value': '22~26', 'confidence': 0.723069},
#    'emotion': {'value': 'neutral', 'confidence': 1.0},
#    'pose': {'value': 'frontal_face', 'confidence': 0.999811}}]}

# %%
detect_result.keys()
# Out:
# dict_keys(['info', 'faces'])

# %%
detect_result['faces']
# Out:
# [{'roi': {'x': 93, 'y': 130, 'width': 160, 'height': 160},
#   'landmark': {'leftEye': {'x': 136, 'y': 176},
#    'rightEye': {'x': 209, 'y': 173},
#    'nose': {'x': 174, 'y': 214},
#    'leftMouth': {'x': 141, 'y': 258},
#    'rightMouth': {'x': 208, 'y': 258}},
#   'gender': {'value': 'male', 'confidence': 0.999973},
#   'age': {'value': '22~26', 'confidence': 0.723069},
#   'emotion': {'value': 'neutral', 'confidence': 1.0},
#   'pose': {'value': 'frontal_face', 'confidence': 0.999811}}]

# %%
detect_result['faces'][0]['roi'] # faces 키가 리스트형
# Out:
# {'x': 93, 'y': 130, 'width': 160, 'height': 160}

# %%
detect_result['faces'][0]['gender']
# Out:
# {'value': 'male', 'confidence': 0.999973}

# %%
detect_result['faces'][0]['emotion']
# Out:
# {'value': 'neutral', 'confidence': 1.0}

# %%
detect_result.values()
# Out:
# dict_values([{'size': {'width': 354, 'height': 472}, 'faceCount': 1}, [{'roi': {'x': 93, 'y': 130, 'width': 160, 'height': 160}, 'landmark': {'leftEye': {'x': 136, 'y': 176}, 'rightEye': {'x': 209, 'y': 173}, 'nose': {'x': 174, 'y': 214}, 'leftMouth': {'x': 141, 'y': 258}, 'rightMouth': {'x': 208, 'y': 258}}, 'gender': {'value': 'male', 'confidence': 0.999973}, 'age': {'value': '22~26', 'confidence': 0.723069}, 'emotion': {'value': 'neutral', 'confidence': 1.0}, 'pose': {'value': 'frontal_face', 'confidence': 0.999811}}]])

# %%
# values로 값을 받고 그 값을 개수에 맞춰 각 변수에 저장함
x, y, w, h=detect_result['faces'][0]['roi'].values()
gender, gender_confidence = detect_result['faces'][0]['gender'].values()
emotion, emo_confidence = detect_result['faces'][0]['emotion'].values()
age, age_confidence = detect_result['faces'][0]['age'].values()
# 사진 위에 얼굴 정보 출력
annotation = f"{gender}:{gender_confidence}\n{emotion}:{emo_confidence}\n{age}:{age_confidence}\n닮은사람 : {test_name}"
print(annotation)
# Out:
# male:0.999973
# neutral:1.0
# 22~26:0.723069
# 닮은사람 : 한승현

# %%
import matplotlib.patches as patches

# img = mpimg.imread("./datas/face_detection1.jpg")
img = mpimg.imread("./datas/aboutme.jpg")
fig, ax = plt.subplots(figsize=(10, 10))
ax.imshow(img)

# 얼굴 인식 박스 그리기
rect_face = patches.Rectangle((x,y),w,h,
                              linewidth=5,
                              edgecolor='r',
                              facecolor='none')

ax.add_patch(rect_face)
plt.text(10, 400, annotation, wrap=True, color='black', fontsize='16')
plt.show()

# %% [markdown]
# ## 유명인 얼굴 인식 일치 확률 구현

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.patches as patches
import requests
import json
from PIL import ImageFile

client_id = "KBSm4KBobPGW62mdUrCX"
client_secret = "7N3EvKDn7e"

# url = "https://openapi.naver.com/v1/vision/face" // 얼굴감지
url = "https://openapi.naver.com/v1/vision/celebrity"  # 마지막 경로를 face로 변경
# files = {'image': open('./datas/face_detection1.jpg', 'rb')}
files = {'image': open('./datas/aboutme.jpg', 'rb')} ################################# <- 여기사진변경 하면 됨
headers = {'X-Naver-Client-Id': client_id, 'X-Naver-Client-Secret': client_secret }

# post() 로 보내기
response = requests.post(url,  files=files, headers=headers)
# print(response.text)
# print(type(response.text)) # type = str

parsed = json.loads(response.text)
# print(parsed)
# print(type(parsed)) # 파이썬 딕셔너리

# 딕셔너리를 json.dumps() 처리하면 json 데이터가 됨
# confidence : 일치률
# value : 값


test =  json.dumps(parsed, indent=4, sort_keys=False, ensure_ascii=False)
test_name = parsed['faces'][0]['celebrity']['value']

## ==============위의 경우는 닮은 사람을 test_name에 저장===================
## ==============아래는 (닮은것들의)비율 및 사진 출력===================
url = "https://openapi.naver.com/v1/vision/face"  # 마지막 경로를 face로 변경
# files = {'image': open('./datas/face_detection1.jpg', 'rb')}
files = {'image': open('./datas/aboutme.jpg', 'rb')}  ################################# <- 여기사진변경 하면 됨
headers = {'X-Naver-Client-Id': client_id, 'X-Naver-Client-Secret': client_secret }

# post() 로 보내기
response = requests.post(url,  files=files, headers=headers)

parsed = json.loads(response.text)

detect_result = json.loads(response.text)
detect_result.keys()
x, y, w, h=detect_result['faces'][0]['roi'].values()
gender, gender_confidence = detect_result['faces'][0]['gender'].values()
emotion, emo_confidence = detect_result['faces'][0]['emotion'].values()
age, age_confidence = detect_result['faces'][0]['age'].values()
# 사진 위에 얼굴 정보 출력
annotation = f"{gender}:{gender_confidence}\n{emotion}:{emo_confidence}\n{age}:{age_confidence}\n닮은사람 : {test_name}"
# print(annotation)

img = mpimg.imread("./datas/aboutme.jpg")  ################################# <- 여기사진변경 하면 됨
fig, ax = plt.subplots(figsize=(10, 10))
ax.imshow(img)

# 얼굴 인식 박스 그리기
rect_face = patches.Rectangle((x,y),w,h,
                              linewidth=5,
                              edgecolor='r',
                              facecolor='none')

ax.add_patch(rect_face)
plt.text(10, 400, annotation, wrap=True, color='black', fontsize='16')
plt.rc('font', family='Malgun Gothic')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.patches as patches
import requests
import json


client_id = "KBSm4KBobPGW62mdUrCX"
client_secret = "7N3EvKDn7e"

# url = "https://openapi.naver.com/v1/vision/face" // 얼굴감지
url = "https://openapi.naver.com/v1/vision/celebrity"  # 마지막 경로를 face로 변경
# files = {'image': open('./datas/face_detection1.jpg', 'rb')}
files = {'image': open('./datas/gil.jpg', 'rb')} ################################# <- 여기사진변경 하면 됨
headers = {'X-Naver-Client-Id': client_id, 'X-Naver-Client-Secret': client_secret }

# post() 로 보내기
response = requests.post(url,  files=files, headers=headers)
# print(response.text)
# print(type(response.text)) # type = str

parsed = json.loads(response.text)
# print(parsed)
# print(type(parsed)) # 파이썬 딕셔너리

# 딕셔너리를 json.dumps() 처리하면 json 데이터가 됨
# confidence : 일치률
# value : 값


test =  json.dumps(parsed, indent=4, sort_keys=False, ensure_ascii=False)
test_name = parsed['faces'][0]['celebrity']['value']

## ==============위의 경우는 닮은 사람을 test_name에 저장===================
## ==============아래는 (닮은것들의)비율 및 사진 출력===================
url = "https://openapi.naver.com/v1/vision/face"  # 마지막 경로를 face로 변경
# files = {'image': open('./datas/face_detection1.jpg', 'rb')}
files = {'image': open('./datas/gil.jpg', 'rb')}  ################################# <- 여기사진변경 하면 됨
headers = {'X-Naver-Client-Id': client_id, 'X-Naver-Client-Secret': client_secret }

# post() 로 보내기
response = requests.post(url,  files=files, headers=headers)

parsed = json.loads(response.text)

detect_result = json.loads(response.text)
detect_result.keys()
x, y, w, h=detect_result['faces'][0]['roi'].values()
gender, gender_confidence = detect_result['faces'][0]['gender'].values()
emotion, emo_confidence = detect_result['faces'][0]['emotion'].values()
age, age_confidence = detect_result['faces'][0]['age'].values()
# 사진 위에 얼굴 정보 출력
annotation = f"{gender}:{gender_confidence}\n{emotion}:{emo_confidence}\n{age}:{age_confidence}\n닮은사람 : {test_name}"
# print(annotation)

img = mpimg.imread("./datas/gil.jpg")  ################################# <- 여기사진변경 하면 됨
fig, ax = plt.subplots(figsize=(10, 10))
ax.imshow(img)

# 얼굴 인식 박스 그리기
rect_face = patches.Rectangle((x,y),w,h,
                              linewidth=5,
                              edgecolor='r',
                              facecolor='none')

ax.add_patch(rect_face)
plt.text(10, 400, annotation, wrap=True, color='black', fontsize='16')
plt.rc('font', family='Malgun Gothic')
plt.show()

# %%
client_id = "KBSm4KBobPGW62mdUrCX"
client_secret = "7N3EvKDn7e"

# url = "https://openapi.naver.com/v1/vision/face" // 얼굴감지
url = "https://openapi.naver.com/v1/vision/celebrity"  # 마지막 경로를 face로 변경
# files = {'image': open('./datas/face_detection1.jpg', 'rb')}
files = {'image': open('./datas/kinji.jpg', 'rb')} ################################# <- 여기사진변경 하면 됨
headers = {'X-Naver-Client-Id': client_id, 'X-Naver-Client-Secret': client_secret }

# post() 로 보내기
response = requests.post(url,  files=files, headers=headers)
print(response.text)
print(type(response.text)) # type = str

parsed = json.loads(response.text)
# print(parsed)
# print(type(parsed)) # 파이썬 딕셔너리

# 딕셔너리를 json.dumps() 처리하면 json 데이터가 됨
# confidence : 일치률
# value : 값


test =  json.dumps(parsed, indent=4, sort_keys=False, ensure_ascii=False)
test_name = parsed['faces'][0]['celebrity']['value']

## ==============위의 경우는 닮은 사람을 test_name에 저장===================
## ==============아래는 (닮은것들의)비율 및 사진 출력===================
url = "https://openapi.naver.com/v1/vision/face"  # 마지막 경로를 face로 변경
# files = {'image': open('./datas/face_detection1.jpg', 'rb')}
files = {'image': open('./datas/kinji.jpg', 'rb')}  ################################# <- 여기사진변경 하면 됨
headers = {'X-Naver-Client-Id': client_id, 'X-Naver-Client-Secret': client_secret }

# post() 로 보내기
response = requests.post(url,  files=files, headers=headers)

parsed = json.loads(response.text)

detect_result = json.loads(response.text)
detect_result.keys()
x, y, w, h=detect_result['faces'][0]['roi'].values()
gender, gender_confidence = detect_result['faces'][0]['gender'].values()
emotion, emo_confidence = detect_result['faces'][0]['emotion'].values()
age, age_confidence = detect_result['faces'][0]['age'].values()
# 사진 위에 얼굴 정보 출력
annotation = f"{gender}:{gender_confidence}\n{emotion}:{emo_confidence}\n{age}:{age_confidence}\n닮은사람 : {test_name}"
print(annotation)

ImageFile.LOAD_TRUNCATED_IMAGES = True

img = mpimg.imread("./datas/kinji.jpg")  ################################# <- 여기사진변경 하면 됨


fig, ax = plt.subplots(figsize=(10, 10))
ax.imshow(img)
# 얼굴 인식 박스 그리기
rect_face = patches.Rectangle((x,y),w,h,
                              linewidth=5,
                              edgecolor='r',
                              facecolor='none')

ax.add_patch(rect_face)
plt.text(10, 400, annotation, wrap=True, color='black', fontsize='16')
plt.rc('font', family='Malgun Gothic')
plt.show()
# Out:
# {"info":{"size":{"width":960,"height":960},"faceCount":1},"faces":[{"celebrity":{"value":"손진영","confidence":0.183699}}]}
# <class 'str'>
# male:0.999999
# smile:0.873093
# 25~29:0.38769
# 닮은사람 : 손진영
